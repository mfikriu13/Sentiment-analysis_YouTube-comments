# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:
		
		# extracting required info
		# from each result object
		for item in video_response['items']:
			
			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])
			
			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:
					
					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']
					
					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'], 
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %%
# isikan dengan api key Anda
api_key = 'xxxxxxxxxxxxxxxxxxxxxx'

# Enter video id
# url video = https://www.youtube.com/watch?v=uynhvHZUOOo
video_id = "uynhvHZUOOo" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2025-02-07T06:50:09Z',
#   '@therealcyberwolfman',
#   '<a href="https://www.youtube.com/watch?v=uynhvHZUOOo&amp;t=255">04:15</a> This is far too optimistic, as many governments and corporations have no plan to be &#39;carbon neutral&#39; by even 2050. And, many climate models don&#39;t take methane into account, which is a MUCH worse greenhouse gas than CO2, especially in the short term, as many consider its effects to be 80 times worse. As for the CO2, itself, it might stay in the atmosphere for centuries or even thousands of years and about 25% of it could stay forever (check out NASA&#39;s graphic: Major Greenhouse Gas Sources, Lifespans, and Possible Added Heat). See what&#39;s happened in just the last few decades and imagine what it&#39;ll be like even one hundred years from now and realise that that&#39;s only the start of what&#39;s coming!',
#   0],
#  ['2025-02-07T06:33:32Z',
#   '@ZjayJD',
#   'Bruh why do the poorest countries get the worst of pollution done by the richest countries just sad 😞',
#   0],
#  ['2025-02-06T20:59:43Z',
#   '@paulschoeters1375',
#   'why dont you talk about the cows and meat industries the cows are responsible for 50 present of  the global warming nobody talks about it  why',
#   0],
#  ['2025-02-06T06:21:26Z',
#   '@surendrakarki8173',
#   'Himalayan nations like Nepal will face a very severe result as we are already facing a rainless winter and no snowfall during winter.',
#   0],
#  ['2025-02-03T19:59:09Z',
#   '@muhammadtehzeeb759',
#   'Effects are quite visible now',
#   1],
#  ['2025-02-03T16:23:19Z',
#   '@jotai99',
#   'Global warming is bad but blaming it all on someone else is sick. China is doing all it can to change themself and stay away from fossil fuels. They are the example for all to follow, what have the west done other than just keep warning the world?',
#   0],
#  ['2025-02-03T11:19:36Z', '@colin_a', 'Total nonsense..', 0],
#  ['2025-02-02T20:14:37Z',
#   '@AmigoAmigo-w5p',
#   '3 Degrees is coming way faster than we ever imagined. Its 2024 and we already got 1.6c',
#   1],
#  ['2025-02-01T09:52:43Z',
#   '@gxjan',
#   '&quot;greed has poisoned man&#39;s souls&quot;<br>(Charles Chaplin)',
#   0],
#  ['2025-01-29T20:58:23Z',
#   '@皮粉孙俪分',
#   'What a load of b, tell governments to practice what they preach, and we could cool the planet with setting of volcanoes purposely, but I don’t buy it Just a money making scheme for the rich the planet heats and cools on its own got nothing to do with humans especially normal citizens cars try the rich with their planes and the wars',
#   0],
#  ['2025-01-29T16:37:48Z',
#   '@krisztinabencze4726',
#   '...and trump left the Paris agreement 😏🫣',
#   1],
#  ['2025-02-06T20:58:27Z',
#   '@MaryLove-d5w',
#   'It’s all about greed, he doesn’t care about future generations.',
#   0],
#  ['2025-01-28T17:23:59Z',
#   '@rafant4545',
#   'Greed will win, as always. Why would not it?',
#   0],
#  ['2025-01-28T14:56:01Z',
#   '@LWRC',
#   'So we need to stop the insanity of making and driving battery cars!!!',
#   0],
#  ['2025-01-27T18:14:48Z',
#   '@alibanah8483',
#   'Who will stop multinational mafias!?',
#   0],
#  ['2025-01-26T15:07:59Z',
#   '@Nibha28',
#   'We are living in a world where a President believes that global warming is hoax. Why would these oligarch bother about climate change? Common citizens of the world will pay the price.',
#   0],
#  ['2025-01-26T13:46:33Z', '@CURIOUSBOY0101', '❤really helpful', 0],
#  ['2025-01-25T05:22:22Z',
#   '@ParagD-l4k',
#   'Once feedback cycles starts, it&#39;s all over..',
#   0],
#  ['2025-01-23T23:08:01Z',
#   '@Consulart77',
#   'Yeah, we have been told so since the 1950s but apparently 8.9 billion people on this planet can do nothing about it…on a more cynical side note, it used to be called global warming. Climate change was the name given by the GOP  to lessen people’s concern about it, as “global warming” sounded too scary. On a more positive note, we will not have to wait long for a real life sequel of Mad Max.',
#   2],
#  ['2025-01-23T21:31:35Z',
#   '@psyklown5198',
#   'Really????? Just check the worlds temperature for the last 150 yrs its the same now as 150 yrs ago. Thsi is all BS from these so called experts.',
#   0],
#  ['2025-01-23T15:46:03Z',
#   '@bishnuprasaddutta8395',
#   'European government thinks if they experience little rise in temperatures during the summer then it&#39;s ok rest of the 11months will be more colder, then there is enough time for the catastrophic events',
#   0],
#  ['2025-01-23T15:14:28Z',
#   '@michaelMcdowell-k9o',
#   'this doc is using the old 75 years from now..<br><br>this means nothing to a person who has not experienced these effects.<br><br>climate chaos is here and this doc is complicit.',
#   1],
#  ['2025-01-23T07:23:32Z',
#   '@nate3915',
#   'It just snowed in the Gulf of Mexico and Florida',
#   1],
#  ['2025-01-23T06:53:52Z',
#   '@salta5859',
#   'We are, in 2025 beginning at 1.5C',
#   2],
#  ['2025-01-23T04:23:09Z',
#   '@tabithacamarillo3789',
#   'And now our convicted felon President Trump just pulled the U.S. out of the Paris Agreement. The worst decision ever made in human history',
#   1],
#  ['2025-01-23T04:13:47Z',
#   '@zlatomirravic3780',
#   'This is the problem economy and desire for attachment and material. Beeing emit more light into space than received. Sun&#39;s  radiation is something silence may understand but do not comprehend fully. Be like water, bread councuslsly. Thus is paradise, the whole space is, there is no other. There will be no new reincarnation in human form, and this is not first time. Since and faith are the same, the only reason is one takes life in his hands, destiny. But there is no logic to depend on. Arahant- Samyak-Sambudhaya- Samma-Sambudhasa <br> This 2 years are the Red dragon.  <br> So be compassionate and show compassion for all beeings.<br> Om Som Hum',
#   0],
#  ['2025-01-22T18:14:02Z',
#   '@drewdam8871',
#   'You are not going to experience this in your lifetime, nor will your offspring. Earth and the whole of the solar system is in a Grand Solar Minimum, 2008 to 2050. The northern hemisphere will experience severe cold beginning already and most certainly by 2030. Buy some nice winter woolies and forget the climate models that this video bangs on about as the models are based on garbage science. This movie is a scare story only. There is absolutely no doubt that the climate of Earth is changing, just as it has since Earth was formed billions of years ago so no surprise there then. At the end of the movie they point out that the climate change is all your fault and they forget all about the Sun which is the cause of our changing weather patterns, and I suggest that we cannot do anything about our star.',
#   0],
#  ['2025-01-23T06:44:36Z', '@dawncryy', 'You&#39;re wrong', 0],
#  ['2025-01-23T12:00:34Z',
#   '@drewdam8871',
#   '@dawncryy\xa0 Wrong about what exactly? All the material that I use is peer-reviewed science. There is no guesswork or religiosity involved. Too many people &#39;believe&#39; in the BBC&#39;s claptrap of &#39;global warming&#39; that they believe and want others to accept as true. This nonsensical loonacy is broadcast across the planet on the World Service. Now, almost everyone is party to the story, and a cult has grown up supporting this nonsense, which is unfortunate as when indoctrinated people remain locked into this false narrative they become unable to reason otherwise and thereby unable to research the matter. The BBC, the IPCC, etc., use paid-for scientists who make lots of money by writing scary stuff. People lap it up and become religiously involved. Please research this subject and be free...',
#   0],
#  ['2025-01-23T12:09:53Z',
#   '@drewdam8871',
#   '@dawncryy\xa0 And, you should know that Earth is at an interstadial in an ongoing Ice-Age. For two million years we have experienced this coldness. The previous Ice-Age lasted for twenty million years, so it will be a while before we warm up. Earth has been much warmer in the distant past and was much greener when there was 1,000 parts per million and more of CO2. Enjoy life, and don&#39;t let them scare you.',
#   0],
#  ['2025-01-24T02:52:05Z', '@dawncryy', '@@drewdam8871 Ur insane', 0],
#  ['2025-01-24T12:38:08Z',
#   '@drewdam8871',
#   '@dawncryy\xa0 Things are not always as they seem. Another comment just asked about how it is known about the current event. I replied that spaceweather from the Sun is predictable with regard to a number of its cycles. There is the 11/22 year cycle beloved by radio hams, the 350 to 400 year cycle to which I have mentioned, and the 12,000 year catastrophe cycle that definitely is worth a mention. The last two cycles are ongoing currently. It is the second, the 350 to 400 year cycle, a Grand Solar Minimum, 2008 to 2050, which is causing the havoc everyone is now aware of. This time around it has the prefix of &#39;Grand&#39; because of its enhanced effects. A visit online to the National Gallery in Trafalgar Square will enable you to see the effect of the previous event. Look up &#39;Frost Fairs&#39; on the River Thames. One-foot thick ice covered the River and the northern hemisphere of Earth suffered COLD. Look today at North America and see that almost the whole has extremely cold weather. It is snowing in Florida, and that has broken all known records.',
#   0],
#  ['2025-01-22T18:08:40Z',
#   '@drewdam8871',
#   'Having reviewed the Economist&#39;s post in this video on YouTube, I hereby note and suggest that the Economist action is one of a troll. A troll is a person or persons who intentionally posts abusive, offensive or inflammatory content online to upset others. Trolls may also post irrelevant comments to derail conversations. <br>Explanation:<br>● Trolls may post controversial things to get a reaction; <br>● Trolls may post messages that cause others to argue or become angry; <br>● Trolls may post messages to get attention or cause trouble; <br>● Trolls may post messages to start arguments and stir up trouble, and<br>● Trolls may post messages to disrupt online communities.',
#   0],
#  ['2025-01-22T17:59:12Z',
#   '@t-bone3657',
#   'Two main factors omitted: You cannot force China &amp; India to stop their massive polluting so to address the rest of the world is a moot point. B) If you are totally serious you would not bring another human into this world. The real problem is not just overpopulation but the fact that the most selfish act in life is to have a child that you cannot afford to have. 50+ years ago we called climate change “the weather” - you greenies are silly 🤪',
#   0],
#  ['2025-01-22T12:24:38Z',
#   '@sankarguha9205',
#   'Solar panels garbadge would be another issue soon.',
#   0],
#  ['2025-01-22T12:16:31Z',
#   '@sankarguha9205',
#   'Hydroelectric projects of power production is of course one of the solutions of climate change. But again the problem is , making hydroelectric power plants on the international rivers causes crisis of natural water flow to downstream neighboring countries. Like China makes many hydroelectric power plants which causes dry or less water flow to the downstream countries. All these points are to be noted.',
#   0],
#  ['2025-01-22T12:09:43Z',
#   '@sankarguha9205',
#   'Fortunately, Bangladesh installed one Nuclear power plant recently, but the Authority wants to stop its progress of installation. There would be two units each having capacity 1200 MW. Now it is being installed again but progress is slow.',
#   0],
#  ['2025-01-22T12:03:28Z',
#   '@sankarguha9205',
#   'Unfortunately, Bangladesh still use fossil fuel for its all power plants. Destroy forest and cut trees to make paper bags for packaging. Burn plastics on the streets in the city even. So who cares for global warming.',
#   0],
#  ['2025-01-22T05:07:07Z',
#   '@ZacharyMorris-n2y',
#   'Im lost in all of this when this data only looks at temperature from only the last 100 years',
#   0],
#  ['2025-01-22T01:53:45Z',
#   '@1Kent',
#   'Some people have been trained to deny the proof of their own eyes.<br>We all know who they are.🐘',
#   2],
#  ['2025-01-21T22:50:01Z',
#   '@gregoryfuzi4745',
#   'Yeah it&#39;s snowed in Louisiana today global warming. And it&#39;s negative two in Michigan.',
#   0],
#  ['2025-01-21T16:36:04Z',
#   '@abijhon13579',
#   'There is a documentary and article of BBC that in 2035 world would be unhabitable.',
#   0],
#  ['2025-01-23T17:15:40Z',
#   '@colacokebottle1',
#   'Nope it will be digital dystopia because you may think climate is the problem but AI will be the problem for you? In 2060 I say we would live a virtual world',
#   0],
#  ['2025-01-21T16:15:15Z',
#   '@nicholas11121',
#   'The problem is that people aren’t having enough kids',
#   0],
#  ['2025-01-21T20:36:10Z', '@Ashtoobaked', 'HAHAHAHAHHAAHAHAHAHAHAHHAA', 1],
#  ['2025-01-21T15:28:12Z',
#   '@ellkir1521',
#   'Fact: Earth has experienced cold periods (informally referred to as “ice ages,” or &quot;glacials&quot;) and warm periods (“interglacials”) on roughly 100,000-year cycles for at least the last 1 million years. The last of these ice age glaciations peaked* around 20,000 years ago. Which means we are in the SEASONAL GLOBAL WARMING PERIOD!. All of the hype and drum beating is a way for scientists to get rich and governments to control the masses.',
#   1],
#  ['2025-01-21T18:21:29Z',
#   '@Bryan-od7nv',
#   'They always measure it from the 1850s to today.  Which would be a quarter inch on a mile long ruler in earth’s history.',
#   0],
#  ['2025-01-21T02:28:47Z',
#   '@The1stKing',
#   '<a href="https://www.youtube.com/watch?v=uynhvHZUOOo&amp;t=320">5:20</a> what about the vast amount of land that is currently unusable because of its low temperature in Russia that will become a fertile land once the global temperature rises?<br>The surface is so large that only a fraction of it is enough to make an enourmous amount of food.',
#   0],
#  ['2025-01-20T15:42:05Z',
#   '@Jesmith-v7n',
#   'the viewers for this should be in the millions.  The oligarchs are set up for survival, the rest of us are mostly dispensable, thus the lack of alarm and we peons just keep rollin along',
#   1],
#  ['2025-01-19T23:51:23Z',
#   '@rolieg81',
#   'Governments should have capped the populations im sorry to say...',
#   0],
#  ['2025-01-19T21:57:49Z',
#   '@noel.sk03',
#   'Well, seems like Europe, North America, Japan and South Korea will have to close borders sooner than ever.',
#   0],
#  ['2025-01-21T15:34:08Z',
#   '@qodeshymchurchwell1851',
#   'Well as of today USA is closed. Oh and the cartel deemed as terrorists',
#   0],
#  ['2025-01-18T16:09:12Z',
#   '@peterh5428',
#   '10 years ago the mean temperatur was 0,06 degrees celsius lower then it is today. I can not go out any more because it is to warm. We only have 8 year to stop all emissions otherwise we all will die from the heat.',
#   1],
#  ['2025-01-21T15:38:54Z',
#   '@qodeshymchurchwell1851',
#   'Lol they said that 10 years ago',
#   0],
#  ['2025-01-17T17:02:49Z',
#   '@Finn.780',
#   'I live in Houston, and evertime theres even a little bit of ice or a bad storm of any kind no matter the type of storm or temperature the power almost always goes out, if not for a couple of minutes it&#39;ll go out for a couple of days. Our infrastructure can&#39;t and probably will never keep us safe in the face of climate change, and not enough people have accepted that reality.',
#   1],
#  ['2025-01-17T05:32:23Z',
#   '@rossdonnnell',
#   'Load of hot air. Climate change has been happening since the world existed. Minuscule (and unproven) rise in global temperatures of less than one degree in 100 years (with potentially 20 percent due to human influence) has more to do with cleaner air and lesss smoke. In any case, I wish it would heat up a bit more. I would burn more carbon to assist this process if I didn’t know it would have no effect whatsoever. At least the ISA will escape this nonsense when Trump puts a line through it. Europe will not be so lucky and will continue to pay for nothing and continue to ruin their own manufacturing and industry.',
#   0],
#  ['2025-01-15T16:36:26Z',
#   '@chieldevries5135',
#   '<a href="https://www.youtube.com/watch?v=uynhvHZUOOo&amp;t=276">4:36</a> I believe this guy is secretly a werewolf.',
#   0],
#  ['2025-01-15T06:32:18Z',
#   '@TheGreatGouki',
#   'Bro’s sideburns are wild….<br><br>But yeah, apparently we are already 1.5C decades earlier than projected. So the next 30 years are gonna be fun. And that’s just on the environmental side of things. Ugh. We don’t deserve the planet.',
#   3],
#  ['2025-01-15T06:26:55Z',
#   '@yoonahkang7384',
#   'fossil fuel and stop eating meat',
#   0],
#  ['2025-01-14T07:37:49Z', '@mickkirby5121', 'Ice age is coming  soon', 0],
#  ['2025-01-12T19:17:51Z', '@redProxy___', 'we&#39;re doomed', 2],
#  ['2025-01-12T05:25:45Z',
#   '@cocogemini6623',
#   'So sad that people the majority of people wont believe climate change. They believe there conspiracy theories.',
#   3],
#  ['2025-01-11T19:34:19Z',
#   '@suteners2111',
#   'we will hit 3C in 2050 or sooner. this video is too cautious',
#   4],
#  ['2025-01-16T19:45:18Z',
#   '@againstviralmisinformation510',
#   'I have been noticing that lately. Some climatologist are being too optimistic',
#   0],
#  ['2025-01-19T21:37:45Z',
#   '@edwardj3070',
#   'That&#39;s not ehat the models say, no matter what the rate of fossil fuel development is',
#   0],
#  ['2025-01-11T08:23:01Z',
#   '@rimor_es_2635',
#   'Climate change is great guys,<br>Many landlocked countries will get their own beaches now🌊🏖️',
#   0],
#  ['2025-01-11T07:10:41Z',
#   '@danycereseu5877',
#   'I think we should tax the countries with the biggest pollution rate not the countries that are stable',
#   2],
#  ['2025-01-10T16:06:08Z',
#   '@marystacey4796',
#   'Im only 56, but i hope im not here when this happens',
#   1],
#  ['2025-01-10T10:58:55Z', '@robertmaloney2255', 'The dinosaurs loved it', 0],
#  ['2025-01-10T02:39:20Z',
#   '@SelfSustainableCity',
#   'The world may burn and seas may rise,  \r<br>Yet in the soil, where wisdom lies,  \r<br>If we return to earth&#39;s embrace,  \r<br>We heal the harm we’ve come to face.  \r<br>For nature whispers, soft and near,  \r<br>In every leaf, a truth so clear.',
#   1],
#  ['2025-01-09T05:50:17Z',
#   '@scoobydo-m1v',
#   '😂 does that include the fact temperature dropped by 1.5deg since the volcano eruption in 1831...so currently we are at the same temperature as then',
#   0],
#  ['2025-01-14T14:46:42Z',
#   '@alfredcampos7268',
#   'sadly not, not everyone can get the same top tier science class from the back of cereal boxes as you',
#   3],
#  ['2025-01-08T23:59:53Z', '@RoninRose-sg1ks', 'Home 🏠', 0],
#  ['2025-01-06T18:40:21Z',
#   '@StevenGottwalt-c2g',
#   'What is Global warming? The sky not warming- up you say it&#39;s our emissions in the atmosphere and how that creating global warming?The moon rotate around Earth (pulling) from the south- pool out to space,<br> There is a lot of heat from transportation businesses homes but still not enough,It&#39;s <br>not liquid for fuel cause it already Burnt can&#39;t feed the Sun, Perhaps it&#39;s from removing the Oil when we remove the Oil we make room for the inner-core to grow since we been removing the Oil over 1000 Volcanoes don&#39;t work were does the Lava go?<br>Tornadoes Hurricanes tsunamis are fromed because We removing the Oil trapping Air drying out the land we live on and the Ocean floors are the thinnest think about it!!!<br>All circular in pattern (Proverbs 21: 20)',
#   0],
#  ['2025-01-24T09:13:48Z', '@Boist-qv1pb', 'Tf you on about', 0],
#  ['2025-01-06T04:15:43Z',
#   '@benlagging2265',
#   'Another Myth Busted: Latest Report Reveals 30 Year Drop in Hurricane Frequency and Power',
#   0],
#  ['2025-01-16T19:47:14Z',
#   '@againstviralmisinformation510',
#   'Dude 2020 was literally the record of Hurricanes in one season. Where in Walmart do you get your education',
#   1],
#  ['2025-01-17T00:51:02Z',
#   '@benlagging2265',
#   '@@againstviralmisinformation510 Over 70 years of actual living.  Do not be a dufus.  Expect insults when you do.<br>Here is some actual information and not just BS.  &quot;The BBC has described Helene as ‘one of the biggest ever storms to hit the US Gulf Coast, with wind gust speeds of 140 mph’. That’s true, but it is still quite a long way behind the 150mph of Camille in 1969, or the 160mph of the Labor Day hurricane of 1935, both of which hit the US before climate change was deemed a major concern.<br><br>The use of hurricanes to spread fear and alarm about global warming has a long and dishonourable history, going back to Al Gore’s 2006 film, An Inconvenient Truth, and beyond. Gore’s genius was in recognising how he could leverage the then recent disaster of Hurricane Katrina and the subsequent flooding of New Orleans to push his climate message.&quot;<br><br>HINT: you are gullible and are being willingly lied to for monetary gain by the few.  That&#39;s not real science.',
#   0],
#  ['2025-01-06T00:40:50Z',
#   '@eM-ed5pz',
#   'Global warming is still propaganda to push wealth from the poor to the rich.',
#   2],
#  ['2025-01-24T09:14:59Z',
#   '@Boist-qv1pb',
#   'Seriously? It&#39;s the same logic as if you close your eyes the world doesn&#39;t exist.',
#   0],
#  ['2025-01-24T14:35:33Z',
#   '@eM-ed5pz',
#   '@Boist-qv1pb\xa0 The World still exists when your eyes are closed along with polar bears',
#   0],
#  ['2025-01-25T06:04:01Z',
#   '@Boist-qv1pb',
#   '@@eM-ed5pzthat&#39;s what I said genius',
#   0],
#  ['2025-01-05T09:40:45Z',
#   '@KingJeffKiller',
#   'We are already 50% there.<br>2025 and we already have 1.55 degree.',
#   3],
#  ['2025-01-04T04:25:20Z',
#   '@GreenGlowNews',
#   'A 3°C rise in global temperatures would be a devastating wake-up call for humanity. This scenario isn&#39;t just a distant possibility—it&#39;s a reality we must strive to avoid. Education through films like this is vital to inspire action and drive change.',
#   4],
#  ['2025-01-03T22:25:52Z', '@BobSmith-k9z', '3C is a lot', 0],
#  ['2025-01-02T02:04:59Z',
#   '@gwohsau6571',
#   'The earth&#39;s climate has changed frequently over millions of years before man and will continue to do so. Fear mongering serves no purpose but to drive the greedy flying around to meetings in jets claiming to save you with 40 dollar light bulbs.',
#   0],
#  ['2025-01-14T14:49:19Z',
#   '@alfredcampos7268',
#   'you are so right, if this conferences didn&#39;t exist, rich people wouldn&#39;t fly around the world',
#   0],
#  ['2025-01-24T09:16:53Z',
#   '@Boist-qv1pb',
#   'It has. It also caused mass extinctions. Species cannot adapt to such fast changes. Planet becomes inhabitable for most if not all.',
#   0],
#  ['2025-01-01T23:32:01Z', '@stevenhibberd4162', 'More lies', 0],
#  ['2025-01-24T09:17:11Z', '@Boist-qv1pb', 'How so', 0],
#  ['2025-01-01T13:47:59Z',
#   '@nickcharles5891',
#   'Let’s see what millions of dead people look like from starvation because of progressive green policies.',
#   1],
#  ['2024-12-30T03:11:17Z',
#   '@mdmamunorrosid2989',
#   'Hey world,,,<br> STOP fighting... <br>Fight for climate change...',
#   2],
#  ['2024-12-29T10:32:47Z', '@sorinhodosan458', '😂😂😂😂😂😂', 1],
#  ['2024-12-29T01:16:37Z',
#   '@JAdams-t6g',
#   'The Western world is causing global heating so you should explain how the Western world will suffer. So many don’t have empathy for people far away.',
#   2],
#  ['2025-01-06T19:18:54Z',
#   '@jacobsukovaty520',
#   'Uh yeah no more then 50% of emissions are from Asia stop with the lies',
#   0],
#  ['2025-01-24T09:18:06Z',
#   '@Boist-qv1pb',
#   '\u200b@@jacobsukovaty520europe and America have been the top historical emitters',
#   0],
#  ['2024-12-26T06:38:20Z', '@Pertence75', 'Hello Woke people', 1],
#  ['2024-12-29T07:04:56Z',
#   '@sheawakeman5422',
#   'hello depressingly misinformed person!',
#   8],
#  ['2024-12-29T07:08:26Z',
#   '@Pertence75',
#   '@sheawakeman5422\xa0 lol you need to like your own reply.. Pathetic...',
#   1],
#  ['2025-01-11T08:18:32Z',
#   '@JdaProductions',
#   '\u2060\u200b\u2060\u200b\u2060\u200b\u2060\u200b\u2060@@Pertence75 You call fighting against Climate Change “Woke”, you should really consider who’s the pathetic one.',
#   4],
#  ['2024-12-25T00:47:45Z',
#   '@Tm-eg2lx',
#   'Stop the scaremongering nonsense,climate alarmists will destroy humanity.<br>What did the world look like last time the temperature was<br> 3 degrees higher.',
#   1],
#  ['2024-12-29T10:45:26Z',
#   '@dresdi',
#   'It is you fools who are destroying humanity, you won&#39;t be leaving these comments when the consequences get to you, get a grip',
#   5],
#  ['2024-12-24T23:19:19Z',
#   '@shaunlynch1016',
#   'only gonna get worse with that idiot trump being pres of US again he wants to increase fossil fuel use the great moronic buffoon',
#   2],
#  ['2024-12-23T12:29:10Z',
#   '@marsbetelgeuse7599',
#   'Don&#39;t worry , we will live another ice age in a few thousand years',
#   1],
#  ['2024-12-23T07:31:11Z',
#   '@vincentoconnor7620',
#   'Came to Australia in 1966 nothing has changed',
#   1],
#  ['2024-12-23T06:30:45Z',
#   '@Daenysthedreamer287',
#   'Peachy. Unfortunately the only thing that would work is to stop all emissions and sequester as much atmospheric carbon as we can.',
#   0],
#  ['2024-12-23T00:43:27Z',
#   '@lonewolfmtnz',
#   'WRONG. +2.26C from preindustrial in 2025 . Add  0.5C for CO2 only in 2026.   Plus dozens of  amplifying irreversible feedbacks. And, were done.',
#   1],
#  ['2024-12-22T07:48:04Z',
#   '@jb3995',
#   'Hahaha flat earther… was there life on Neptune…..guess at best. Mars we need a rover. All science is a guess until proven…. No proof whatsoever that the earth is not in a cycle….that is always has been.',
#   0],
#  ['2024-12-22T04:10:14Z',
#   '@gollumraider5044',
#   'We are already above 1.5 which we were not supposed to reach untill 2050.<br>Now we will probably reach 3 at the same year.',
#   1],
#  ['2024-12-21T15:22:39Z',
#   '@BonitaBrandt',
#   'This past summer was the first time my patio plants all died due to global warming. It was a record-breaking 112 degrees in the southern U. S.',
#   0],
#  ['2024-12-21T15:04:38Z',
#   '@GlobalGreenways',
#   '&quot;Three degrees of global warming would drastically transform our planet, leading to rising sea levels, extreme weather events, and widespread ecosystem disruptions. It’s a stark reminder of the urgent need for collective action to reduce emissions and prioritize sustainable living for future generations.&quot;',
#   0],
#  ['2024-12-17T22:31:04Z',
#   '@freedomsports3365',
#   'Temperature of the atlantic ocean in Açores  summer 2024 reach 27 ⁰, ceicius...., world record, the maximum was 24⁰......, on the present day, 17 december 2024 water is at 20⁰....., so... next summer will be hotter...., this is VERY BAD !!!!!',
#   1],
#  ['2024-12-16T02:44:13Z', '@michaeldavis8617', 'It’s inevitable', 3],
#  ['2024-12-15T23:04:23Z',
#   '@StephenGrover-zc4hp',
#   'Wait to see the weather in the Tribulation period, coming.<br>Read the book of Revelation in the Bible and see!',
#   2],
#  ['2024-12-15T05:25:54Z',
#   '@daddydancer1555',
#   'we have to give up what we consider our rights for &quot;standard of living&quot;, but that requires such a radical change in behaviour.  So few can concieve of having to do without what we come to regard as &quot;normal&quot; consumption. We will be forced to it unfortunately and Im watching as the wealthy in the background are preparing themselves as they know whats coming. Social upheaval is already happening worldwide, and they have already put in huge efforts to protect their own interests. I wont be around long enough but when i walk past families giving birth to more children i find myself in tears for those innocent children and for the ignorance of &quot;normality&quot; that the parents believe they have even as the &quot;standard of living&quot; is falling and instead of recognising that its not governments that care causing it but greater forces they wont see because they are blindsided by the wealthy who manipulate our media and tell us what to think.',
#   3],
#  ['2024-12-14T17:00:57Z',
#   '@fredschoemaker7042',
#   'If that would have happened then that should of happed in 2012 to 2024<br>2024 TO 2035 MAJOR COLD COLD COLD FREEZING COLD FREEZING COLD FREEZING COLD FREEZING COLD HEAVY HEAVY HEAVY HEAVY SNOW SNOW SNOW SNOW SNOW WINTERS IN A ROW TO CLOSE UP THE TECTONIC PLATES FOR ABOUT A 25 YEAR PEROID EVERY 50 YEARS',
#   0],
#  ['2024-12-14T14:43:41Z', '@workphone1402', 'BS!', 0],
#  ['2024-12-14T14:43:12Z',
#   '@workphone1402',
#   'Tell the people about weather manipulation?',
#   0],
#  ['2024-12-14T14:42:35Z', '@workphone1402', 'FEARMONGERING PROPAGANDA!', 1],
#  ['2024-12-14T05:07:24Z',
#   '@de_bestburger',
#   'Why did i have to be born into this mess',
#   8],
#  ['2024-12-13T22:22:54Z',
#   '@EliSmith-bq8po',
#   'Do you know guys this is propaganda',
#   1],
#  ['2024-12-17T11:58:19Z',
#   '@nsbd90now',
#   'All the people who didn&#39;t do well in school agree with you.',
#   9],
#  ['2024-12-13T18:23:16Z',
#   '@ObservableObserver',
#   'And they tell me that I should have children, smh.',
#   7],
#  ['2024-12-13T12:32:12Z',
#   '@KimJongUn-x1o',
#   'All problems would be solved beautifully if we can make the wealthy individuals pay for the climate change!',
#   6],
#  ['2024-12-12T14:02:20Z',
#   '@Hyrule_Castle-s1m',
#   'I live in south Italy, and while i know that here it&#39;s normal for the climate to be hot, atleast during Winter it used to be cold here too, now here it&#39;s december and if i look outside the window it looks more like spring/summer',
#   1],
#  ['2024-12-11T00:30:21Z', '@otoulapan', 'We are at 3c now! 2024.', 1],
#  ['2024-12-10T09:45:37Z',
#   '@martyn_g',
#   'People in developed countries are only concerned with what happens within their bubble. When it does hit that bubble, it’ll be too late.',
#   3],
#  ['2024-12-10T06:28:08Z',
#   '@infiniteworfare5089',
#   'this is an overreaction lie. 3 degrees is absolutely nothing. it becomes a problem when its 15+ degrees above.',
#   0],
#  ['2024-12-29T07:16:49Z', '@sheawakeman5422', '2/10 bait 😭', 5],
#  ['2024-12-09T14:42:31Z',
#   '@VirginiaDellal',
#   'Watch &quot;Climate The Movie&quot; 🍿 with your children ❤ ❤',
#   0],
#  ['2024-12-09T05:50:46Z',
#   '@onlydreaming9301',
#   'This guy’s beard is bugging me😠',
#   0],
#  ['2024-12-07T07:29:46Z',
#   '@krustenhund',
#   '<a href="https://www.youtube.com/watch?v=uynhvHZUOOo&amp;t=230">3:50</a> I&#39;m afraid reality will be even worse.',
#   2],
#  ['2024-12-05T06:08:58Z',
#   '@deadassfunny3553',
#   'If i said it once, ive said it a thousand times. The biggest danger to climate change is Liberal tears condensing into the atmosphere',
#   1],
#  ['2024-12-04T12:55:06Z',
#   '@florinnatu',
#   'we live at the end of the last ice-age. humans do 2% in global warming. where is the water coming from for the rising sea levels? 😂 it.s all such bc. our problem is the air and water quality, but planet will get warmer with or without people and industry',
#   1],
#  ['2024-12-03T22:15:15Z',
#   '@gh5972',
#   'Only 3 degrees? It won’t stop there.',
#   3],
#  ['2024-12-03T06:52:59Z',
#   '@TanyaOwens',
#   'Greed and a disregard for the ecology and the environment is what got us in this predicament. People are not going to suddenly change the wealthy are going to remain wealthy because they have ways to soften the blow to themselves they&#39;ll be all fine so they&#39;re not going to change and they own the world. So sadly they will be widespread suffering and conditions won&#39;t improve. The tipping point will be humanity running its course',
#   0],
#  ['2024-12-02T21:26:20Z',
#   '@aq3681',
#   '&quot;By the end of the century&quot;. Are you serious? We will be at 3C in 2040 or earlier. Wake up!',
#   4],
#  ['2024-12-02T07:19:53Z',
#   '@GhislaindeTournemire',
#   '3°c c’est une facture de chauffage en baisse 👍. Plus chaud et moins de chauffage.',
#   0],
#  ['2024-11-30T16:47:49Z',
#   '@leodeleeuw2303',
#   'What a pack of lies !  Its been a lot warmer than + 3°C and  without ice at the poles for most of the existence of the planet earth ! With less deserts and  everything teeming with live !  The reality is that the earth is cooling down with more and more ice ages and shorter and shorter warmer intervals like the present . Besides that there is NO such thing as a global temperature and  &quot;CO2&quot; as a green house gas is just BS !',
#   0],
#  ['2024-12-03T22:17:04Z', '@gh5972', 'Talk about BS 💩', 2],
#  ['2024-11-27T10:24:01Z',
#   '@isaklee6403',
#   'this is unrealistic, there will much fast heating up the planet as 2024 shows',
#   0],
#  ['2024-11-27T07:02:54Z',
#   '@Sharon-yk7xm',
#   'Climate change is big lies made up by BP the planet is chaingeing because the earth is chainging',
#   0],
#  ['2024-11-27T18:48:25Z',
#   '@vasusharma4519',
#   'Planet is actually on its way to become cooler not hot. What if I say your life is also a lie.',
#   0],
#  ['2024-11-29T07:02:52Z',
#   '@davet2429',
#   'Yeah and the Earth&#39;s flat too.',
#   0],
#  ['2024-11-29T07:09:51Z',
#   '@vasusharma4519',
#   '@@Sharon-yk7xm what if I tell you that your existence is a lie?',
#   0],
#  ['2024-11-26T21:35:44Z',
#   '@robertellis333',
#   'But trump says that it’s fake news…….so it must be fake',
#   1],
#  ['2024-12-27T04:51:11Z', '@Mark-Hi2', 'How can you believe in an orange', 1],
#  ['2024-11-26T19:35:52Z',
#   '@legatilegions8055',
#   'We need need to bio engineer our climate, that means we need the right technology, thats why i think all the billions spent on reparations for climate damage should be spent on developing new technology, it would serve us all better on the long term',
#   1],
#  ['2024-11-26T16:23:58Z',
#   '@bandit2048',
#   'This video was made three years ago - it&#39;s already a lot worse three years down the line. Nobody wants to even try to tackle it because it&#39;s too big an issue - after all, it&#39;s hardly a vote puller to tell everyone they need to radically change their lifestyles. So it&#39;s ignored - until it will be too big to ignore. Mother Nature is having her say - she started with gentle admonishments but that clearly didn&#39;t do anything so she&#39;s brought out the big guns now.',
#   3],
#  ['2024-11-26T15:10:34Z',
#   '@stefanleu9246',
#   'Your projected sea level rise is far too small and represents a minimum in current models. Due to Arctic and Antarctic glaciers being lifted of the ground by current sea level rise and warmer sea water, and the glaciers as such once freed of obstacles will flow much faster into the oceans, more then one, to several meters of sea level rise must be taken into account. Furthermore the many feedback mechanisms that will amplify warming will be triggered with certainty at 3 degrees, so that warming can&#39;t be stopped anymore by net zero emissions and will progress much further.',
#   2],
#  ['2024-11-25T07:44:15Z',
#   '@farjanatonny211',
#   'I am so scared 😟 i am only 9 years old 😓',
#   2],
#  ['2024-12-19T18:55:34Z',
#   '@Records_Old',
#   '\u200b@JosuéBolamuI&#39;m 17 and I&#39;m still scared of this.',
#   1],
#  ['2024-11-24T16:41:29Z', '@H8XME', 'Fake news', 0],
#  ['2024-11-26T14:41:45Z', '@dopeeast-f7x', 'How old are you?', 6],
#  ['2024-11-29T07:03:47Z',
#   '@davet2429',
#   'Alright Trump get back in your hole.',
#   2],
#  ['2024-11-23T00:05:58Z',
#   '@water4sure',
#   'Meanwhile western countries are currently having a mass migration to their respective countries and this will ultimately have a significant impact on their environmental footprint. Starmer from UK already undermining to rid of farmers, replace with the likes of Blackrock, CEO Larry Fink, who will earmark green spaces of land for development to accommodate for mass migration and business hubs. Can anyone see the hypocrisy here??😮',
#   0],
#  ['2024-11-22T05:07:40Z',
#   '@GolDFish-if1ov',
#   'For me I don&#39;t really mind it&#39;s only just 3 degrees. I&#39;m from a tropical country and it&#39;s always hot here. I&#39;m used to hotter climates.🍷🗿',
#   0],
#  ['2024-11-27T18:50:14Z',
#   '@vasusharma4519',
#   '3° AVERAGE temperature you have no idea about how climate works. <br>Climate change is lethal for humanity',
#   5],
#  ['2024-12-06T11:49:11Z', '@mirthepeeters65', '🤦\u200d♀️', 2],
#  ['2024-11-20T23:53:06Z',
#   '@Myfavoriteplanet',
#   'Because climate change isn’t a distant future—it’s here, affecting our lives, our health, and our planet. We must stop it. Now!',
#   7],
#  ['2024-11-20T20:10:50Z',
#   '@amadeuz819',
#   'Its only the planet curing itself from an infection, like if we look at humans in a similar way as bacteria in the gut. As long as the balance is kept we are just fine and our body feels no need to fix the problem and &quot;flush&quot; em out... As long as we keep balance on the planet the planet would not need to &quot;flush&quot; us out...<br><br>I prepared the popcorn for the show already 20+ years ago when no body listened even if we in the north were shouting, funny thing is that we in the north probably have bigger chance to survive this so maybe you should have listened 20 years ago instead of making our society even worse to make some money, money and some more money while reproducing like &quot;4b to 8b in like 40 years&quot; to feed your greed and other needs.<br><br>Mother earth will repair the damage, lets hope she only sees us as a &quot;gut bacteria&quot; that grew out of control and not as an enemy to her system.',
#   2],
#  ['2024-11-19T22:18:45Z',
#   '@adamsfamily4060',
#   'We are all to blame for this. The technology we are using to make comments ect results in pollution and waste . Better switch off.',
#   0],
#  ['2024-11-19T04:19:37Z',
#   '@JustAGirl-y1p',
#   'In Illinois you only need a Jean jacket - I remember when we needed insulated puffer coats …',
#   1],
#  ['2024-11-16T06:18:32Z',
#   '@GlobalWarmingFraud',
#   '97% of climate scientists agree that anthropogenic global warming fraud is directing large amounts of money into their bank accounts.',
#   0],
#  ['2024-11-15T17:51:41Z', '@tomlochem4399', '😂😂', 0],
#  ['2024-11-12T21:32:17Z',
#   '@starupiva',
#   'Hi climate researcher and scientist here. Just wanted to tell that we won&#39;t survive 3 degrees of warming. People will fall to the geound like flies. Its that dangerous. Even if you literally throw yourself into a freezer, theres no chance.',
#   0],
#  ['2024-11-12T04:00:12Z',
#   '@theainewsguy',
#   'I am from Puducherry, India and face more heat than the larger in 14 years. It&#39;s regularly 100 deg C.',
#   0],
#  ['2024-11-22T05:08:31Z',
#   '@GolDFish-if1ov',
#   'That nothing. I experienced 200 deg C. I&#39;m used to living with it. It doesn&#39;t bother me.',
#   0],
#  ['2025-01-24T09:35:02Z', '@Boist-qv1pb', '100 degree celcius? 💀 Idiotic', 0],
#  ['2024-11-11T10:42:25Z', '@TonyTeAtlas', 'MAN MADE BY AMERICAN  NASA', 0],
#  ['2024-11-11T08:18:18Z',
#   '@But1non',
#   'Hahaha. Since when have climate models been CORRECT?',
#   0],
#  ['2024-12-27T04:53:01Z',
#   '@Mark-Hi2',
#   'Since when people have become ignorant?',
#   1],
#  ['2024-11-11T07:11:26Z',
#   '@violetamartin4227',
#   'Governments won&#39;t do it, it´s us. Only us through our consumption.',
#   1],
#  ['2024-11-10T16:52:32Z',
#   '@nk99988',
#   'I Live in india Maharashtra...we are facing extream heat waves...',
#   0],
#  ['2024-11-10T16:11:24Z',
#   '@markschuette3770',
#   'do not let trump continue his denial of Climate Change and the 6th Great Extinction !!!',
#   4],
#  ['2024-11-09T22:02:39Z',
#   '@jlluna2633',
#   'Prior to Trump&#39;s victory, we were already halfway there hitting 1.5°C this year. We will see this world BY 2050!',
#   4],
#  ['2024-11-09T21:00:27Z',
#   '@Iwidiufuewls',
#   'We humans left this world with such a mess who agrees with me?',
#   0],
#  ['2024-11-09T18:29:08Z',
#   '@MK87pll',
#   'W Polsce przydałoby się 3 stopnie więcej szczególnie zimą 😂😂😂😂😂',
#   0],
#  ['2024-11-08T20:04:19Z',
#   '@TaylorReeds-g6s',
#   'And now that Trump won 2024 it will never be fixed',
#   5],
#  ['2024-11-09T21:48:53Z', '@jlluna2633', '3°C maybe 4°C by 2050', 0],
#  ['2024-11-08T18:15:02Z',
#   '@smalrast',
#   '&quot;World Leaders&quot;  are you serious? The Americans have just voted in a clown who believes climate warming is a hoax. Humanity is lost.',
#   10],
#  ['2024-11-09T21:50:33Z',
#   '@jlluna2633',
#   'It is. We will hit accelerate emissions, destroy natural carbon sinks and increase the CO2 and other gas concentration more and more. We are at 1.5°C, 2°C by 2030, 3° by 2050',
#   0],
#  ['2024-11-26T07:14:49Z',
#   '@SRDPS2',
#   'Assuming Trump and MAGA even know about &quot;World Leader&quot;<br><br>They are already isolated themselves',
#   0],
#  ['2024-11-06T08:33:12Z',
#   '@Davidlin-w4l',
#   'Take care of yourselves, you have lost a person of great light to change something in this world that is so bad, a person who does not respect others or respect the climate or the environment has taken the presidency, I have a book that is going to come out soon in Spain in Spanish(for now) talking about a truth that many need to know.',
#   0],
#  ['2024-11-05T23:08:34Z',
#   '@EricZuber-z6l',
#   'When I was growing up in Ohio back in the 1950&#39;s and 60&#39;s I remember having snow on the ground on Halloween. We have recently been hearing from family that temperatures have been in the 60~80° range for some time.(11/5/24)',
#   1],
#  ['2024-11-05T22:36:07Z',
#   '@dougwheeler4549',
#   'Best advice is to ask the opinion of the Dinosaurs. Global warming was upon the earth millions of years before the human animal arrived. There was no word called Global Warming or even any language to write or speak of Global warming.<br>Yet there was Global warming.<br><br>So the Dinosaurs are the ones to ask.<br>They know.',
#   0],
#  ['2024-11-07T00:21:52Z',
#   '@oberonpanopticon',
#   'Even if humans weren’t the cause of global warming, it’s obviously happening so we should be trying to do something to stop it',
#   4],
#  ['2024-11-07T11:47:30Z',
#   '@MrMezmerized',
#   'Actually the comet impact was followed by several degrees of global cooling over the course of about 8 million years. But I get your point. The thing is: no climatologist ever said climates don&#39;t change naturally. What they point at are anomalous changes that seem totally unnatural.',
#   1],
#  ['2024-11-24T00:47:32Z',
#   '@fabienclaveau9098',
#   'Dinosaurs would answer: Well, we were not scientifically or technologically advanced like humans are. I mean, digging oil from the ground? Building and running power plants? Flying around the world in aircrafts? Driving cars? Running AI computing centers? Those are all human created. So sorry, humans are responsible for this mess. At least have the decency to recognize it, if not for you, then do it for your children.',
#   2],
#  ['2024-11-26T14:43:03Z',
#   '@dopeeast-f7x',
#   'We are destroying forests at an extremely high rate, rivers and oceans are being polluted with toxic waste, coral reefs are dying, we have lost imense amounts of biodiversity and we are producing extreme amounts of carbon dioxide, NOx and methane. How are we NOT haveing an effect on the climate you doughnut?',
#   1],
#  ['2024-11-05T06:11:27Z',
#   '@antonleimbach648',
#   'We are already at 1.5 so hitting 3 degrees is far more likely.',
#   1],
#  ['2024-11-05T01:29:24Z',
#   '@rebeccaketner816',
#   'That hairy guy makes this seem kinda sketchy',
#   0],
#  ['2024-11-04T15:36:05Z',
#   '@Pranav-y3c',
#   'Thank you for your valuable information',
#   1],
#  ['2024-11-03T14:55:47Z',
#   '@riffmondo9733',
#   'What will a lithium and cobalt polluted world be like after this climate change madness has reached fruition.<br><br>The Economist has investors to serve as usual.',
#   0],
#  ['2024-11-07T11:58:07Z',
#   '@MrMezmerized',
#   'Manufacturers are busy developing better batteries and other types. Tesla uses cobalt-free LFP batteries for two years now. There is still much progress possible. The same cannot be said for ICEs after 140 years. But given your rethoric, I don&#39;t think you are very interested in facts like these.',
#   0],
#  ['2024-11-02T19:15:20Z',
#   '@DTDan-b8r',
#   'I remember the fear caused in 1970 when projected population growth was going to double the population on the same resources.  They were wrong; the population tripled, but farmers figured out how to feed them.<br>We are at a solar maximum.  Shouldn&#39;t we take steps to avoid the next ice age? Which way is the right way?  We have no idea.',
#   1],
#  ['2024-11-07T00:22:40Z',
#   '@oberonpanopticon',
#   'It’s 22° Celsius in November in Canada. How much longer can you bury your head in the sand for?',
#   0],
#  ['2024-11-07T13:11:16Z',
#   '@MrMezmerized',
#   'We actually do have an idea. Then Sun has gone through 110-120 year cycles. Schwabe cycle 25 (peak in 2026) is but the first within this bigger cycle. And looking back at those, any chance at a new ice age is still quite a few centuries away, if not millennia. Current global warming will have compensated for the -8 °C drop within roughly 350 years already.  See, the 2nd half of the 120 year cycle that ended in 2020 came with +1.1 °C instead of -0.4 °C like the two times before. That&#39;s a +1.5 °C anomaly in 60 years, with indications that it&#39;s getting worse.',
#   0],
#  ['2024-11-02T03:56:27Z',
#   '@Joyce-v7f',
#   'We all need to be worried about an increase in globally warming. It is certainly deadly.',
#   0],
#  ['2024-11-01T00:23:10Z',
#   '@Anti-carnist-666',
#   'Can&#39;t wait till I see humans screaming for help. Specially the ones who didn&#39;t think this was going to happen. ❤',
#   1],
#  ['2024-10-31T18:53:56Z',
#   '@xavisanchez7522',
#   'This is the perfect muslc ambient for documentaries and historical narratives that is ideal for portraying empires , current history of modern day countries and dictators like napoleon, and events like the absolutism era',
#   0],
#  ['2024-10-31T18:53:45Z',
#   '@xavisanchez7522',
#   'This is the perfect muslc ambient for documentaries and historical narratives that is ideal for portraying empires , current history of modern day countries and dictators like napoleon, and events like the absolutism era',
#   0],
#  ['2024-10-31T12:53:37Z',
#   '@resilientfarmsanddesignstu1702',
#   'What causes global warming? The release of greenhouse gases caused by the use of fossil fuels right? Partially correct. There are two other factors: 1) the loss of living biomass -- or the conversion of resources that would otherwise support them into non-living things. What&#39;s the connection? If Carbon can&#39;t accumulate in the standing stock of living biomass, then it must accumulate somewhere, and it does! In our atmosphere and in our oceans! Thus global warming and loss of ecological biomass are one and the same problem. 2) the rate of greenhouse gas emissions. Natural systems can&#39;t keep up. Solution: Simultaneously reduce the rate of greenhouse gas emissions, embark on a massive adaptive ecological restoration focusing on the establishment of food forests capable of sustaining BOTH human AND ecological organisms. Place as much non-residential structures and infrastructure as possible underground or in space, reserving the surface of the Earth for living things. Create an ecologically literate population that recognizes that human survival, health and well-being is totally dependent upon the survival, health and well-being of or internal and external ecosystem, redefine wealth as the same, build an ecologically based and constrained economy using ecologically based and ecologically constrained technology. Act as the keystone species and build up the capacity of the ecosystem to sustain human life, using the excess productive capacity to grow the human economy. That&#39;s our only viable way forward. Let&#39;s get started!',
#   1],
#  ['2024-10-31T12:31:59Z',
#   '@resilientfarmsanddesignstu1702',
#   'The problem is actually believing that a top down solution will be forthcoming. It will not... it never does. So, only a bottom up solution is viable. How? Start with yourself. Place ALL of your critical subsistence life-support system requirements under your own ownership and control -- many of which are rooted in the survival, health and well-being of the ecosystem. Partner eith others in mutualistic networks until colectively, you are self-sufficient and self-sustaining. By subsistence, I mean all those support systems that you require to live and retain your health and well-being NOT an accumultion of material wealth. Expand the network, considering the subsistence needs of the group as a whole. Repeat at progressively higher levels of aggregation up to and including the world as a whole.',
#   0],
#  ['2024-10-30T02:38:30Z',
#   '@BrotherDudeBro',
#   'Back in the 90&#39;s and early 2000&#39;s, we never had any aircondiion and can sleep on the porch at noon. Now, we can hardly take a nap on the porch by 9am.',
#   0],
#  ['2024-10-29T03:47:53Z',
# ...
#   0],
#  ['2024-04-23T04:55:11Z',
#   '@ronnycalloway6937',
#   'The Earth will be okay. The surface dwellers may have issues.',
#   0],
#  ['2024-04-23T10:57:15Z',
#   '@damianoasteriti8530',
#   'Tell me you&#39;re autistic without telling me you&#39;re autistic: ☝️',
#   0],
#  ['2024-04-22T21:03:08Z',
#   '@haa729',
#   'Remember Global Cooling in the 60s through the 90s 😂 now it&#39;s Global Warming because people started to see right through their BS and yall now believe this 😂😂😂',
#   0],
#  ['2024-04-22T08:34:17Z',
#   '@Liminal_Galaxie',
#   'Hi from Cambodia where right now it is 39°C (feels like 46). 3 degrees in 2024 is already wishful thinking. We need divestment from fossil fuels and protection for natural resources NOW',
#   0],
#  ['2024-04-23T11:04:23Z',
#   '@damianoasteriti8530',
#   'Tell that to India and China...',
#   0],
#  ['2024-04-21T16:03:51Z',
#   '@terenceiutzi4003',
#   'During the medieval warm period it was that warm vineyards covered northern Scotland!',
#   0],
#  ['2024-04-21T08:26:01Z', '@TGWazoo1', 'The computer models are flawed.', 1],
#  ['2024-04-20T21:31:47Z', '@mitsmats', 'was nice knowing you guys', 0],
#  ['2024-04-20T14:13:49Z',
#   '@user-Rocket-Fest',
#   '3*C weather change?? In almost every place on Earth the temp change from nite to mid day is more than 3 degrees',
#   0],
#  ['2024-04-23T08:44:05Z',
#   '@Mrmemyself',
#   'Wow you&#39;re so smart it&#39;s not like small AVERAGE temperature change can have massive consequences overall.',
#   1],
#  ['2024-04-23T13:43:44Z',
#   '@user-Rocket-Fest',
#   '@@Mrmemyself you only have to ask who&#39;s killing the pig with all this climate drivel?',
#   0],
#  ['2024-04-23T15:29:28Z',
#   '@Mrmemyself',
#   '\u200b@@user-Rocket-Fest Genuinely who do you think is profiting out of pushing climate change &quot;propaganda&quot;? On the flip side who could be profiting from denying it?',
#   0],
#  ['2024-04-24T06:32:07Z',
#   '@user-Rocket-Fest',
#   '@@Mrmemyself Oh I don&#39;t know, but well north of $500,000,000,000 of tax payers funds have so far been doshed out to 1000&#39;s of Private Firms. Since when did the Tax payers fund Private Enterprise??',
#   0],
#  ['2024-04-26T07:05:12Z',
#   '@Mrmemyself',
#   '\u200b@@user-Rocket-Fest How could small firms get power to manipulate the government to give them so much money?<br>Meanwhile fossil fuels are one of the largest industries overall and they have been actively fighting real research,funding biased/fake research and generally trying to post-pone change for as long as possible. It&#39;s uncomfortable that climate change is real and human driven but the vast majority of research is saying exactly that.',
#   0],
#  ['2024-04-20T11:50:20Z',
#   '@annuranjan3218',
#   'Whole world needs to control population growth,to minimise carbon emission and resource consumption',
#   0],
#  ['2024-04-21T05:11:59Z',
#   '@damianoasteriti8530',
#   '&quot;Only white people need to stop their growth, they are eight percent of the global population and are going extinct, but it&#39;s all their fault&quot;<br><br><b>RUBBING HANDS FURIOUSLY</b>',
#   0],
#  ['2024-04-29T14:30:26Z',
#   '@r.a.6459',
#   'The world can support billions, but not billionaires.<br>Climate change is the result of GREED.',
#   0],
#  ['2024-04-20T10:12:19Z',
#   '@Freedomisintelligence',
#   'In 1896, a seminal paper by Swedish scientist Svante Arrhenius first predicted that changes in atmospheric carbon dioxide levels could substantially alter the surface temperature through the greenhouse effect. In 1938, Guy Callendar connected carbon dioxide increases in Earth&#39;s atmosphere to global warming. 100 years later people didn&#39;t take global warming seriously in the 1990&#39;s. 30 years later people are still not taking it seriously. Well the warnings were given over 100 years ago and nobody listened and it could of been prevented with alternative technologies. Money destroyed the planet. Is it possible that the human race did the same thing on mars and escaped to planet earth millions of years ago. If earths magnetic field shifts due to global warming then a great flood of the earth will happen then the oceans will boil off from the sun bombarding our planet from a shift in our protective field thus earth becomes mars. We need to find another home or face the same fate as mars. We can make mars habitable in a 50 year timeline and stop the earth from a global catastrophe if everyone worked together. Money is just a thing people made up and can be discarded. When it comes to the human races survival then money is irrelevant.',
#   1],
#  ['2024-04-19T20:11:01Z',
#   '@MsRenatoj',
#   'É  só  uma mentira, não está  acontecendo nada disso. Entretanto,  tem muita gente ganhando fortunas com a propagação dessa farsa.',
#   1],
#  ['2024-04-19T13:38:39Z',
#   '@juliarubacka5875',
#   'I just recommend everyone learn how to clean water, how to use permaculture to keep water in your garden… Grow trees and make mulching around.. Is time to understand how important is knowledge about permaculture…',
#   0],
#  ['2024-04-19T02:55:08Z',
#   '@fredschoemaker7042',
#   'This Happens Every 50 Years Wake Up The Tectonic Plates Will Close In 2035 After Major Cold Freezing Snowy Winters = Then The Tectonic Plates Will Stay Closed For The Next. 25 Years And Will Retain 1.225 Kilotons Of Surface Water Each Year. For 25 Years And Start Again Heating Up The Earth And Releasing. Major Extreme Natural Disaster Every 50 Years Wake Up',
#   0],
#  ['2024-04-18T15:55:01Z',
#   '@miked5106',
#   'I dispute the hypothesis bc it violates basic laws of thermal dynamics. I dont need to count polar bears or tree rings if the model is fatally flawed.  It&#39;s not at all political or emotional.  It&#39;s just basic science.  I don&#39;t care why people manipulate it.  You can debate that.  The fact is, it&#39;s poor science let&#39;s move on.',
#   0],
#  ['2024-04-23T08:45:44Z',
#   '@Mrmemyself',
#   'How does it violate laws of thermodynamics?',
#   0],
#  ['2024-04-18T05:36:50Z',
#   '@LegentLim',
#   'There are many large meteorites in Space that hit the Sun, causing extremely large explosions to occur continuously on the surface of the Sun. If this happens, will the temperature and sea level of the Earth rise significantly ?',
#   0],
#  ['2024-04-18T00:15:19Z',
#   '@salta5859',
#   'But they are still burning bushes...and this does not help the climate too..',
#   0],
#  ['2024-04-17T12:19:45Z',
#   '@julienrockingham-ip4co',
#   'This is for the parents to figure out',
#   0],
#  ['2024-04-16T05:49:05Z',
#   '@Karma0330',
#   'People are running behind money and ignoring the main problem global warming.',
#   1],
#  ['2024-04-22T21:12:25Z',
#   '@haa729',
#   'No such thing as that, they used to call it global cooling because we were all going to freeze to ☠️ by 2020 and since that didn&#39;t happen they changed it to global warming and we&#39;re all gonna burn to ☠️ oh the horrors 😱 but it won&#39;t happen, next it&#39;ll be global  drying and then global wetting and who knows what else these freaks will think of to keep you scared of your own shadow.',
#   0],
#  ['2024-04-23T08:50:37Z',
#   '@Mrmemyself',
#   '\u200b@@haa729 science changes and actual scientist never thought that earth would cool, do you think that almost every respected university,scientist and other platforms are manipulated for the sake of what exactly?<br>I swear you people are almost as dumb as flat earthers.',
#   3],
#  ['2024-04-23T11:08:28Z',
#   '@damianoasteriti8530',
#   '\u200b\u200b@@Mrmemyself&quot;respected university scientist&quot; hahahahahaha',
#   0],
#  ['2024-04-23T15:39:12Z',
#   '@Mrmemyself',
#   '\u200b@@damianoasteriti8530it&#39;s ok to question stuff but not to be ignorant and go with &quot;muh logic&quot; if we went around figuring things out this way we&#39;d still be in the middle ages,climate change deniers are unable to provide a reliable source of their beliefs while there are hundreds of studies saying that climate change is real and human driven. I guess it&#39;s more comfortable to be believe everything is fine.',
#   1],
#  ['2024-04-24T12:57:26Z',
#   '@damianoasteriti8530',
#   '@@Mrmemyself are you paid to pretend your own stupidity?<br><br>There is overwhelming evidence against global warming, not the other way around and you like to talk about science as if it was an end, science is merely the tool of the current dominating religion, it&#39;s rooted in spiritual mysticism, more precisely jewish kabbalah and the teachings of the zohar...',
#   0],
#  ['2024-04-16T02:02:20Z',
#   '@ofiasdfnosdf',
#   'You liars at &quot;The Economist&quot; are going to be held accountable.  Every single one of you.  You will sit there with a smile on your face, cashing in while the bottom third of the population suffers the deadly consequences of pushing this &quot;climate crisis&quot; lie and cut off their means of energy, STARVING THEM.',
#   0],
#  ['2024-04-16T00:14:38Z',
#   '@Chris-lz1fs',
#   'The thing is, it&#39;s everybody&#39;s problem, not just governments. If we all don&#39;t make an effort to start looking after our planet, we&#39;re all going to suffer. Maybe not this generation or the next, but there will come a time when there&#39;s going to be a sudden massive, world wide shift in the climate. That&#39;s what is going to cause the most damage as it&#39;ll be so sudden, nobody will be prepared for it. After that, the damage to the climate will be irreversible and quite possibly it&#39;ll spiral out of control.',
#   0],
#  ['2024-04-15T13:03:02Z', '@Jefferson1969-u4s', 'Myth', 0],
#  ['2024-04-21T05:16:41Z', '@damianoasteriti8530', 'Jewish lie', 0],
#  ['2024-04-14T20:20:14Z',
#   '@graziflorida4377',
#   '3 DEGREE WILL DESTROY LIFE ON PLANET, THAT IDIOT DOESN&#39;T UNDERSTAND ANYTHING ABOUT  CLIMATE AND BIOLOGY',
#   0],
#  ['2024-04-14T20:17:23Z',
#   '@graziflorida4377',
#   'WE ARE ALREADY ABOVE 2 !!!',
#   0],
#  ['2024-04-14T20:14:56Z',
#   '@graziflorida4377',
#   'We are there, by 2026 no life on Planet.<br>PROF GUY MC PHERSON',
#   0],
#  ['2024-04-13T18:10:47Z',
#   '@FutureCommentary1',
#   'I have max 45 years on earth. Please confirm this is happening after me.',
#   0],
#  ['2024-04-13T08:14:15Z',
#   '@vinay.ambhore',
#   'What about Mumbai India in 3 degree world?',
#   0],
#  ['2024-04-13T01:47:30Z',
#   '@sparetire3',
#   'Meanwhile world leaders leaders eat beef and fly in jets to discuss when technology connects the world with the internet. Climate change is political and profitable and the things that should be done arent done.',
#   2],
#  ['2024-04-11T19:30:16Z',
#   '@ufoyoutellme',
#   '3 degrees is scary , but at a scale of 1 to 10 we’re at .4 not even 1 . At . 2  all the vegetation will DIE , ?',
#   0],
#  ['2024-04-23T08:53:12Z', '@Mrmemyself', 'We are at 1,3 actually.', 0],
#  ['2024-04-11T17:55:04Z',
#   '@michaelhurst6562',
#   'See what something that&#39;s NEVER GOING TO HAPPEN looks like. Don&#39;t buy into this garbage people do your research. LEARN THE TRUTH.',
#   0],
#  ['2024-04-11T01:15:52Z',
#   '@How-Dare-You-Canada',
#   'Sounds like another DEI scam to me.',
#   0],
#  ['2024-04-10T11:30:45Z',
#   '@surajghagare1667',
#   'Our very existence is at stake...🔴⚠ as we are already in the 6th mass Extinction 💀 phase. The only way we can avoid this Catastrophe is by going Vegan 🥦🥕🌽 and Minimalist🤏 in everything for life, primarily by procreating less or not even a single 👶, as this Giant Problem of Global warming 🌎📛 and Climate change is Anthropogenic, hence human population must be limited additionally 🌍 can only take care of 2-3 Billion people properly that too if we use less harmful technogy and ecofriendly management of all the processes, moreover you are wise enough to understand that it&#39;s completely nonsensical to bring own child in this polluted World 🌎 just to suffer hard 🔥🥵😭🥶💧till Brutal Death...💥💀💥. So, play it cool, take care of yourself and the lives/nature🌿🍃around you, Thanks...💚🙏🙏🙏',
#   2],
#  ['2024-04-10T08:46:23Z', '@lisajones4352', 'Sea walls?!', 0],
#  ['2024-04-10T08:45:47Z',
#   '@lisajones4352',
#   'Detoriation is here. Unbearable  Violence is next.',
#   0],
#  ['2024-04-09T06:58:08Z',
#   '@shidiskas',
#   'He he he, faraons were using similar methods to make people obedient by scaring people about sun eclipse',
#   0],
#  ['2024-04-08T21:39:04Z', '@marykali3603', 'No not really', 0],
#  ['2024-04-08T15:01:14Z',
#   '@dominiccobb6470',
#   'nothing will change. ever. just give up.',
#   0],
#  ['2024-04-08T03:21:48Z',
#   '@jacksonlee3771',
#   'Global warming is a hoax!!! CO2 is the main driver of global warming apparently.  You expel CO2. You are the problem. If you are that committed to the hoax do something about it. You catch my drift. Back in the 70s &amp; 80s it was global cooling. That did not work so they changed tactics.',
#   0],
#  ['2024-04-23T08:54:31Z',
#   '@Mrmemyself',
#   'Who changed tactics? What do they aim to accomplish?',
#   0],
#  ['2024-04-23T09:14:30Z',
#   '@jacksonlee3771',
#   '@@Mrmemyself enslaving you, me and the rest of the non billionaires.',
#   0],
#  ['2024-04-23T11:35:37Z',
#   '@damianoasteriti8530',
#   '\u200b@@Mrmemyselfthe jews are &quot;they&quot; and their goal is so vile and evil that it goes beyond your comprehension and beyond your imagination, they are truly the spawns of satan',
#   0],
#  ['2024-04-07T09:45:23Z',
#   '@michaelwalsh9145',
#   'See what propaganda looks like, can you explain how all these doom mongering predictions always contain the words could, maybe, possibly, IF like you just used? It’s because you don’t have a clue what the future holds.',
#   0],
#  ['2024-04-05T20:59:20Z',
#   '@pablojablo6371',
#   'Stopped watching the second he was wearing a mask.',
#   0],
#  ['2024-04-23T11:16:12Z',
#   '@damianoasteriti8530',
#   'Just another muzzled braindead npc...',
#   0],
#  ['2024-04-05T10:02:33Z',
#   '@espomaths',
#   'Brace yourselves, we are inevitably going there, and likely much sooner than at the end of the century.',
#   0],
#  ['2024-04-05T07:31:11Z',
#   '@spiridonnspiridonn4596',
#   'Don`t  space solar power plants scare anyone? / А космические солнечные электростанции никого не пугают? <br>    Идея и планы построить космические солнечные электростанции и доставлять из Космоса энергию на Землю для обеспечения ею потребностей в масштабах континентов не представляются продуманными с общеметодологической ( ф и л о с о ф с к о й ) точки зрения. <br>       На протяжении 2-х миллиардов лет Природа при помощи фотосинтеза аккумулировала энергию Солнца, поступающую на Землю, и   к о н с е р в и р о в а л а   её в остатках растений, тем самым снижая окружающую температуру на Земле. Врезалось в память когда-то прочитанное, что если бы не поглощение растениями поступающей энергии Солнца, то на пустынной Земле установилась бы температура значительно выше 100 градусов. В обобщенном приближении можно считать, что в течение последних 200 лет разбросанные по континентам Земли тепловые электростанции (на угле, нефти, газе и другом топливе) обеспечивали энергетические потребности человечества, сжигая при этом законсервированные Природой энергетические ресурсы Солнца, поступавшие на Землю в течение 2-х миллиардов лет. Сжигание сопровождалось 1) выделением тепла; 2) вредными химическими выбросами. А потребляемая электроэнергия в конечном итоге практически преобразовывалась в тепло. Вот и получилось, что дополнительно к текущей солнечной, поступающей на Землю, энергия от работы электростанций способствовала медленному сдвигу теплового баланса (и, соответственно, температуры) на Земле. Расплата вылилась в ныне сплошной поток природных катаклизмов. В общем случае, заложенное в упомянутую идею   д о п о л н и т е л ь н о е    до существующего природного поступление энергии на Землю из Космоса , в конечном итоге (даже без вредных химических выбросов!) будет приводить к дальнейшему повышению установившейся температуры на Земле. А <b>не</b> к решению проблемы глобального потепления... <br>      Другое дело, если осваивать и массово использовать для земных потребностей аккумуляцию и консервацию солнечной энергии, природным путем поступающей   с е й ч а с  на Землю. <br>[05.04.2024.]',
#   0],
#  ...]

# %%
df = pd.DataFrame(comments, columns=['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount'])
df
# Out:
#                 publishedAt      authorDisplayName  \
# 0      2025-02-07T06:50:09Z   @therealcyberwolfman
# 1      2025-02-07T06:33:32Z                @ZjayJD
# 2      2025-02-06T20:59:43Z     @paulschoeters1375
# 3      2025-02-06T06:21:26Z     @surendrakarki8173
# 4      2025-02-03T19:59:09Z    @muhammadtehzeeb759
# ...                     ...                    ...
# 10284  2021-10-30T12:27:10Z            @jayvee0311
# 10285  2021-10-30T11:05:22Z  @fridereekmelikyan965
# 10286  2021-10-30T11:05:03Z        @fredbloggs5902
# 10287  2021-10-30T11:02:50Z           @shawnc01980
# 10288  2021-10-30T11:01:59Z      @andrewturner8491
#
#                                              textDisplay  likeCount
# 0      <a href="https://www.youtube.com/watch?v=uynhv...          0
# 1      Bruh why do the poorest countries get the wors...          0
# 2      why dont you talk about the cows and meat indu...          0
# 3      Himalayan nations like Nepal will face a very ...          0
# 4                          Effects are quite visible now          1
# ...                                                  ...        ...
# 10284  @@jonathanedwardgibson what if it was always l...          1
# 10285  Snow in texas and in EU , probably global warm...          0
# 10286  Humans now easily have the knowledge and abili...          0
# 10287  Geoengineering haarp DARPA weather warfare mot...          0
# 10288                Don’t you just love fear mongering?          2
#
# [10289 rows x 4 columns]

# %%
df.to_csv('dataset_komentar.csv', index=False)
